# %%
import pymorphy2

from nltk.tokenize import word_tokenize

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
def analyze_word(word):
    P = morph.parse(word)
    max_score = P[0].score
    return [(p.word, p.normal_form, p.tag) for p in P if p.score == max_score]


def analyze_text(text):
    lemmas = []
    for word in word_tokenize(text):
        lemmas.append(analyze_word(word))
    return lemmas

# %%
FICTION_TEXT = 'Я был здоров, молод, весел, деньги у меня не переводились, заботы еще не успели завестись - я жил без оглядки, делал что хотел, процветал, одним словом. Мне тогда и в голову не приходило, что человек не растение и процветать ему долго нельзя. Молодость ест пряники золоченые, да и думает, что это-то и есть хлеб насущный; а придет время - и хлебца напросишься. Но толковать об этом не для чего.'
SCIENCE_TEXT = 'Описаны абелевы группы A и B такие, что группа гомоморфизмов Hom(A,B) является артиновым модулем над кольцом эндоморфизмов группы B. Описание групп A и B, для которых группа Hom(A,B) является артиновым модулем над кольцом эндоморфизмов группы A, сведена к случаю, когда группа A не имеет кручения, а группа B либо квазициклическая группа, либо делимая группа без кручения. Охарактеризованы абелевы группы A и B, для которых группа Hom(A,B) есть нётеров модуль над кольцом E(A) или E(B). Исследование произвольной абелевой группы с нётеровым слева кольцом эндоморфизмов сведено к исследованию группы без кручения с нётеровым слева кольцом эндоморфизмов. Исследование группы с нётеровым справа кольцом эндоморфизмов осталось незавершённым. Описаны сепарабельные абелевы группы без кручения с нётеровыми слева или справа кольцами эндоморфизмов.'
WEBFORUM_TEXT = 'Сап двач, учусь на втором курсе. Понял, что выбранная специальность - явно не мой конёк, и посему решил пойти сдать дополнительные ЕГЭ для поступления на первый курс новой специальности. Я ранее сдавал обществознание, но по глупости снова вписал его в список (думал, что балл очень низкий). Затем посмотрел и увидел, что балл нормальный и есть все шансы попасть на бюджет. Если я откажусь от сдачи обществознания, старые баллы не аннулируются? Пикча рандом)'

# %%
analyze_text(FICTION_TEXT)
# Out:
# [[('я', 'я', OpencorporaTag('NPRO,1per sing,nomn'))],
#  [('был', 'быть', OpencorporaTag('VERB,impf,intr masc,sing,past,indc'))],
#  [('здоров', 'здоровый', OpencorporaTag('ADJS,Qual masc,sing'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('молод', 'молодой', OpencorporaTag('ADJS,Qual masc,sing'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('весёл', 'весёлый', OpencorporaTag('ADJS,Qual masc,sing'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('деньги', 'деньга', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('у', 'у', OpencorporaTag('PREP'))],
#  [('меня', 'я', OpencorporaTag('NPRO,1per sing,accs'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('переводились',
#    'переводиться',
#    OpencorporaTag('VERB,impf,intr plur,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('заботы', 'забота', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('ещё', 'ещё', OpencorporaTag('PRCL'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('успели', 'успеть', OpencorporaTag('VERB,perf,intr plur,past,indc'))],
#  [('завестись', 'завестись', OpencorporaTag('INFN,perf,intr'))],
#  [('-', '-', OpencorporaTag('PNCT'))],
#  [('я', 'я', OpencorporaTag('NPRO,1per sing,nomn'))],
#  [('жил', 'жить', OpencorporaTag('VERB,impf,intr masc,sing,past,indc'))],
#  [('без', 'без', OpencorporaTag('PREP'))],
#  [('оглядки', 'оглядка', OpencorporaTag('NOUN,inan,femn sing,gent')),
#   ('оглядки', 'оглядка', OpencorporaTag('NOUN,inan,femn plur,nomn')),
#   ('оглядки', 'оглядка', OpencorporaTag('NOUN,inan,femn plur,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('делал', 'делать', OpencorporaTag('VERB,impf,tran masc,sing,past,indc'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('хотел', 'хотеть', OpencorporaTag('VERB,impf,tran masc,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('процветал',
#    'процветать',
#    OpencorporaTag('VERB,impf,intr masc,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('одним', 'один', OpencorporaTag('ADJF,Apro plur,datv'))],
#  [('словом', 'слово', OpencorporaTag('NOUN,inan,neut sing,ablt')),
#   ('словом', 'словом', OpencorporaTag('CONJ,Prnt'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('мне', 'я', OpencorporaTag('NPRO,1per sing,datv'))],
#  [('тогда', 'тогда', OpencorporaTag('ADVB,Dmns'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('в', 'в', OpencorporaTag('PREP'))],
#  [('голову', 'голова', OpencorporaTag('NOUN,inan,femn sing,accs'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('приходило',
#    'приходить',
#    OpencorporaTag('VERB,impf,intr neut,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('человек', 'человек', OpencorporaTag('NOUN,anim,masc sing,nomn'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('растение', 'растение', OpencorporaTag('NOUN,inan,neut sing,nomn')),
#   ('растение', 'растение', OpencorporaTag('NOUN,inan,neut sing,accs'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('процветать', 'процветать', OpencorporaTag('INFN,impf,intr'))],
#  [('ему', 'он', OpencorporaTag('NPRO,masc,3per,Anph sing,datv'))],
#  [('долго', 'долго', OpencorporaTag('ADVB'))],
#  [('нельзя', 'нельзя', OpencorporaTag('PRED,pres'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('молодость', 'молодость', OpencorporaTag('NOUN,inan,femn sing,nomn')),
#   ('молодость', 'молодость', OpencorporaTag('NOUN,inan,femn sing,accs'))],
#  [('ест', 'есть', OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'))],
#  [('пряники', 'пряник', OpencorporaTag('NOUN,inan,masc plur,nomn')),
#   ('пряники', 'пряник', OpencorporaTag('NOUN,inan,masc plur,accs'))],
#  [('золочёные', 'золочёный', OpencorporaTag('ADJF plur,nomn')),
#   ('золочёные', 'золочёный', OpencorporaTag('ADJF inan,plur,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('да', 'да', OpencorporaTag('PRCL'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('думает', 'думать', OpencorporaTag('VERB,impf,intr sing,3per,pres,indc')),
#   ('думает', 'думать', OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('это-то', 'это-то', OpencorporaTag('PRCL'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('есть', 'есть', OpencorporaTag('INTJ')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr sing,3per,pres,indc')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr plur,3per,pres,indc')),
#   ('есть', 'есть', OpencorporaTag('INFN,impf,tran'))],
#  [('хлеб', 'хлеб', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [('насущный', 'насущный', OpencorporaTag('ADJF,Qual masc,sing,nomn')),
#   ('насущный', 'насущный', OpencorporaTag('ADJF,Qual inan,masc,sing,accs'))],
#  [(';', ';', OpencorporaTag('PNCT'))],
#  [('а', 'а', OpencorporaTag('CONJ'))],
#  [('придёт', 'прийти', OpencorporaTag('VERB,perf,intr sing,3per,futr,indc'))],
#  [('время', 'время', OpencorporaTag('NOUN,inan,neut sing,accs'))],
#  [('-', '-', OpencorporaTag('PNCT'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('хлебца', 'хлебец', OpencorporaTag('NOUN,inan,masc sing,gent'))],
#  [('напросишься',
#    'напроситься',
#    OpencorporaTag('VERB,perf,intr sing,2per,futr,indc'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('но', 'но', OpencorporaTag('CONJ'))],
#  [('толковать', 'толковать', OpencorporaTag('INFN,impf,tran'))],
#  [('об', 'о', OpencorporaTag('PREP Vpre'))],
#  [('этом', 'это', OpencorporaTag('NPRO,neut sing,loct'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('для', 'для', OpencorporaTag('PREP'))],
#  [('чего', 'что', OpencorporaTag('NPRO,neut sing,gent'))],
#  [('.', '.', OpencorporaTag('PNCT'))]]

# %%
analyze_text(SCIENCE_TEXT)
# Out:
# [[('описаны', 'описать', OpencorporaTag('PRTS,perf,past,pssv plur'))],
#  [('абелевы', 'абелев', OpencorporaTag('ADJF,Poss plur,nomn')),
#   ('абелевы', 'абелев', OpencorporaTag('ADJF,Poss inan,plur,accs'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [('такие', 'такой', OpencorporaTag('ADJF,Apro plur,nomn'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('гомоморфизмов',
#    'гомоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('hom', 'hom', OpencorporaTag('LATN'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('является',
#    'являться',
#    OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'))],
#  [('артиновым', 'артиновое', OpencorporaTag('NOUN,inan,neut sing,ablt')),
#   ('артиновым', 'артиновое', OpencorporaTag('NOUN,inan,neut plur,datv')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual masc,sing,ablt')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual neut,sing,ablt')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual plur,datv'))],
#  [('модулем', 'модуль', OpencorporaTag('NOUN,inan,masc sing,ablt'))],
#  [('над', 'над', OpencorporaTag('PREP'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('b.', 'b.', OpencorporaTag('LATN'))],
#  [('описание', 'описание', OpencorporaTag('NOUN,inan,neut sing,accs'))],
#  [('групп', 'группа', OpencorporaTag('NOUN,inan,femn plur,gent'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('для', 'для', OpencorporaTag('PREP'))],
#  [('которых', 'который', OpencorporaTag('ADJF,Apro,Subx,Anph plur,gent'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('hom', 'hom', OpencorporaTag('LATN'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('является',
#    'являться',
#    OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'))],
#  [('артиновым', 'артиновое', OpencorporaTag('NOUN,inan,neut sing,ablt')),
#   ('артиновым', 'артиновое', OpencorporaTag('NOUN,inan,neut plur,datv')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual masc,sing,ablt')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual neut,sing,ablt')),
#   ('артиновым', 'артиновый', OpencorporaTag('ADJF,Qual plur,datv'))],
#  [('модулем', 'модуль', OpencorporaTag('NOUN,inan,masc sing,ablt'))],
#  [('над', 'над', OpencorporaTag('PREP'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('сведена', 'свести', OpencorporaTag('PRTS,perf,past,pssv femn,sing'))],
#  [('к', 'к', OpencorporaTag('PREP'))],
#  [('случаю', 'случай', OpencorporaTag('NOUN,inan,masc sing,datv'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('когда', 'когда', OpencorporaTag('CONJ'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('имеет', 'иметь', OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'))],
#  [('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut sing,gent')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('а', 'а', OpencorporaTag('CONJ'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [('либо', 'либо', OpencorporaTag('CONJ'))],
#  [('квазициклическая',
#    'квазициклический',
#    OpencorporaTag('ADJF femn,sing,nomn'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('либо', 'либо', OpencorporaTag('CONJ'))],
#  [('делимая', 'делимый', OpencorporaTag('ADJF,Qual femn,sing,nomn')),
#   ('делимая',
#    'делить',
#    OpencorporaTag('PRTF,impf,tran,pres,pssv femn,sing,nomn'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('без', 'без', OpencorporaTag('PREP'))],
#  [('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut sing,gent')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,accs'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('охарактеризованы',
#    'охарактеризовать',
#    OpencorporaTag('PRTS,perf,past,pssv plur'))],
#  [('абелевы', 'абелев', OpencorporaTag('ADJF,Poss plur,nomn')),
#   ('абелевы', 'абелев', OpencorporaTag('ADJF,Poss inan,plur,accs'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('для', 'для', OpencorporaTag('PREP'))],
#  [('которых', 'который', OpencorporaTag('ADJF,Apro,Subx,Anph plur,gent'))],
#  [('группа', 'группа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('hom', 'hom', OpencorporaTag('LATN'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('есть', 'есть', OpencorporaTag('INTJ')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr sing,3per,pres,indc')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr plur,3per,pres,indc')),
#   ('есть', 'есть', OpencorporaTag('INFN,impf,tran'))],
#  [('нётеров', 'нётер', OpencorporaTag('NOUN,inan,masc plur,gent')),
#   ('нётеров', 'нётеров', OpencorporaTag('NOUN,inan,masc sing,nomn')),
#   ('нётеров', 'нётеров', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [('модуль', 'модуль', OpencorporaTag('NOUN,inan,masc sing,nomn'))],
#  [('над', 'над', OpencorporaTag('PREP'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('e', 'e', OpencorporaTag('LATN'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('a', 'a', OpencorporaTag('LATN'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('или', 'или', OpencorporaTag('CONJ'))],
#  [('e', 'e', OpencorporaTag('LATN'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('b', 'b', OpencorporaTag('LATN'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('исследование',
#    'исследование',
#    OpencorporaTag('NOUN,inan,neut sing,nomn'))],
#  [('произвольной',
#    'произвольный',
#    OpencorporaTag('ADJF,Qual femn,sing,loct'))],
#  [('абелевой', 'абелев', OpencorporaTag('ADJF,Poss femn,sing,gent')),
#   ('абелевой', 'абелев', OpencorporaTag('ADJF,Poss femn,sing,datv')),
#   ('абелевой', 'абелев', OpencorporaTag('ADJF,Poss femn,sing,ablt')),
#   ('абелевой', 'абелев', OpencorporaTag('ADJF,Poss femn,sing,loct'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('с', 'с', OpencorporaTag('PREP'))],
#  [('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,ablt')),
#   ('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,GNdr,Ms-f,Pltm,Surn plur,datv'))],
#  [('слева', 'слева', OpencorporaTag('ADVB'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('сведено', 'свести', OpencorporaTag('PRTS,perf,past,pssv neut,sing'))],
#  [('к', 'к', OpencorporaTag('PREP'))],
#  [('исследованию',
#    'исследование',
#    OpencorporaTag('NOUN,inan,neut sing,datv'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('без', 'без', OpencorporaTag('PREP'))],
#  [('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut sing,gent')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,accs'))],
#  [('с', 'с', OpencorporaTag('PREP'))],
#  [('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,ablt')),
#   ('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,GNdr,Ms-f,Pltm,Surn plur,datv'))],
#  [('слева', 'слева', OpencorporaTag('ADVB'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('исследование',
#    'исследование',
#    OpencorporaTag('NOUN,inan,neut sing,nomn'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('с', 'с', OpencorporaTag('PREP'))],
#  [('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,ablt')),
#   ('нётеровым',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,GNdr,Ms-f,Pltm,Surn plur,datv'))],
#  [('справа', 'справа', OpencorporaTag('ADVB')),
#   ('справа', 'справа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('кольцом', 'кольцо', OpencorporaTag('NOUN,inan,neut sing,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('осталось',
#    'остаться',
#    OpencorporaTag('VERB,perf,intr neut,sing,past,indc'))],
#  [('незавершённым', 'незавершённый', OpencorporaTag('ADJF masc,sing,ablt')),
#   ('незавершённым', 'незавершённый', OpencorporaTag('ADJF neut,sing,ablt')),
#   ('незавершённым', 'незавершённый', OpencorporaTag('ADJF plur,datv'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('описаны', 'описать', OpencorporaTag('PRTS,perf,past,pssv plur'))],
#  [('сепарабельные', 'сепарабельный', OpencorporaTag('ADJF plur,nomn')),
#   ('сепарабельные', 'сепарабельный', OpencorporaTag('ADJF inan,plur,accs'))],
#  [('абелевы', 'абелев', OpencorporaTag('ADJF,Poss plur,nomn')),
#   ('абелевы', 'абелев', OpencorporaTag('ADJF,Poss inan,plur,accs'))],
#  [('группы', 'группа', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('без', 'без', OpencorporaTag('PREP'))],
#  [('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut sing,gent')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('кручения', 'кручение', OpencorporaTag('NOUN,inan,neut plur,accs'))],
#  [('с', 'с', OpencorporaTag('PREP'))],
#  [('нётеровыми',
#    'нётеров',
#    OpencorporaTag('NOUN,anim,GNdr,Ms-f,Pltm,Surn plur,ablt'))],
#  [('слева', 'слева', OpencorporaTag('ADVB'))],
#  [('или', 'или', OpencorporaTag('CONJ'))],
#  [('справа', 'справа', OpencorporaTag('ADVB')),
#   ('справа', 'справа', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('кольцами', 'кольцо', OpencorporaTag('NOUN,inan,neut plur,ablt'))],
#  [('эндоморфизмов',
#    'эндоморфизм',
#    OpencorporaTag('NOUN,inan,masc plur,gent'))],
#  [('.', '.', OpencorporaTag('PNCT'))]]

# %%
analyze_text(WEBFORUM_TEXT)
# Out:
# [[('сап', 'сап', OpencorporaTag('NOUN,inan,masc sing,nomn')),
#   ('сап', 'сап', OpencorporaTag('NOUN,inan,masc sing,accs')),
#   ('сап', 'сапа', OpencorporaTag('NOUN,inan,femn plur,gent'))],
#  [('двач', 'двач', OpencorporaTag('NOUN,anim,masc sing,nomn'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('учусь', 'учиться', OpencorporaTag('VERB,impf,intr sing,1per,pres,indc'))],
#  [('на', 'на', OpencorporaTag('PREP'))],
#  [('втором', 'второе', OpencorporaTag('NOUN,inan,neut sing,loct')),
#   ('втором', 'два', OpencorporaTag('ADJF,Anum masc,sing,loct')),
#   ('втором', 'два', OpencorporaTag('ADJF,Anum neut,sing,loct'))],
#  [('курсе', 'курс', OpencorporaTag('NOUN,inan,masc sing,loct'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('понял', 'понять', OpencorporaTag('VERB,perf,tran masc,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('выбранная',
#    'выбрать',
#    OpencorporaTag('PRTF,perf,tran,past,pssv femn,sing,nomn'))],
#  [('специальность',
#    'специальность',
#    OpencorporaTag('NOUN,inan,femn sing,accs'))],
#  [('-', '-', OpencorporaTag('PNCT'))],
#  [('явно', 'явно', OpencorporaTag('ADVB'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('мой', 'мой', OpencorporaTag('ADJF,Apro masc,sing,nomn')),
#   ('мой', 'мой', OpencorporaTag('ADJF,Apro inan,masc,sing,accs')),
#   ('мой', 'мыть', OpencorporaTag('VERB,impf,tran sing,impr,excl'))],
#  [('конёк', 'конёк', OpencorporaTag('NOUN,anim,masc sing,nomn')),
#   ('конёк', 'конёк', OpencorporaTag('NOUN,inan,masc sing,nomn')),
#   ('конёк', 'конёк', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('посему', 'посему', OpencorporaTag('ADVB'))],
#  [('решил', 'решить', OpencorporaTag('VERB,perf,tran masc,sing,past,indc'))],
#  [('пойти', 'пойти', OpencorporaTag('INFN,perf,intr'))],
#  [('сдать', 'сдать', OpencorporaTag('INFN,perf,tran'))],
#  [('дополнительные', 'дополнительный', OpencorporaTag('ADJF plur,nomn')),
#   ('дополнительные', 'дополнительный', OpencorporaTag('ADJF inan,plur,accs'))],
#  [('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,nomn')),
#   ('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,gent')),
#   ('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,datv')),
#   ('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,accs')),
#   ('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,ablt')),
#   ('егэ', 'егэ', OpencorporaTag('NOUN,inan,masc,Sgtm,Fixd,Abbr sing,loct'))],
#  [('для', 'для', OpencorporaTag('PREP'))],
#  [('поступления', 'поступление', OpencorporaTag('NOUN,inan,neut sing,gent'))],
#  [('на', 'на', OpencorporaTag('PREP'))],
#  [('первый', 'один', OpencorporaTag('ADJF,Anum masc,sing,nomn'))],
#  [('курс', 'курс', OpencorporaTag('NOUN,inan,masc sing,nomn'))],
#  [('новой', 'новый', OpencorporaTag('ADJF,Qual femn,sing,gent'))],
#  [('специальности',
#    'специальность',
#    OpencorporaTag('NOUN,inan,femn sing,loct'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('я', 'я', OpencorporaTag('NPRO,1per sing,nomn'))],
#  [('ранее', 'ранее', OpencorporaTag('ADVB'))],
#  [('сдавал', 'сдавать', OpencorporaTag('VERB,impf,tran masc,sing,past,indc'))],
#  [('обществознание',
#    'обществознание',
#    OpencorporaTag('NOUN,inan,neut sing,nomn')),
#   ('обществознание',
#    'обществознание',
#    OpencorporaTag('NOUN,inan,neut sing,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('но', 'но', OpencorporaTag('CONJ'))],
#  [('по', 'по', OpencorporaTag('PREP'))],
#  [('глупости', 'глупость', OpencorporaTag('NOUN,inan,femn sing,datv'))],
#  [('снова', 'снова', OpencorporaTag('ADVB'))],
#  [('вписал', 'вписать', OpencorporaTag('VERB,perf,tran masc,sing,past,indc'))],
#  [('его', 'он', OpencorporaTag('NPRO,masc,3per,Anph sing,accs'))],
#  [('в', 'в', OpencorporaTag('PREP'))],
#  [('список', 'список', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [('(', '(', OpencorporaTag('PNCT'))],
#  [('думал', 'думать', OpencorporaTag('VERB,impf,intr masc,sing,past,indc')),
#   ('думал', 'думать', OpencorporaTag('VERB,impf,tran masc,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('балл', 'балл', OpencorporaTag('NOUN,inan,masc sing,nomn')),
#   ('балл', 'балл', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [('очень', 'очень', OpencorporaTag('ADVB'))],
#  [('низкий', 'низкий', OpencorporaTag('ADJF,Qual masc,sing,nomn'))],
#  [(')', ')', OpencorporaTag('PNCT'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('затем', 'затем', OpencorporaTag('ADVB,Dmns'))],
#  [('посмотрел',
#    'посмотреть',
#    OpencorporaTag('VERB,perf,tran masc,sing,past,indc'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('увидел', 'увидеть', OpencorporaTag('VERB,perf,tran masc,sing,past,indc'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('что', 'что', OpencorporaTag('CONJ'))],
#  [('балл', 'балл', OpencorporaTag('NOUN,inan,masc sing,nomn')),
#   ('балл', 'балл', OpencorporaTag('NOUN,inan,masc sing,accs'))],
#  [('нормальный', 'нормальный', OpencorporaTag('ADJF,Qual masc,sing,nomn')),
#   ('нормальный',
#    'нормальный',
#    OpencorporaTag('ADJF,Qual inan,masc,sing,accs'))],
#  [('и', 'и', OpencorporaTag('CONJ'))],
#  [('есть', 'есть', OpencorporaTag('INTJ')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr sing,3per,pres,indc')),
#   ('есть', 'быть', OpencorporaTag('VERB,impf,intr plur,3per,pres,indc')),
#   ('есть', 'есть', OpencorporaTag('INFN,impf,tran'))],
#  [('все', 'весь', OpencorporaTag('ADJF,Apro plur,nomn'))],
#  [('шансы', 'шанс', OpencorporaTag('NOUN,inan,masc plur,nomn'))],
#  [('попасть', 'попасть', OpencorporaTag('INFN,perf,intr'))],
#  [('на', 'на', OpencorporaTag('PREP'))],
#  [('бюджет', 'бюджет', OpencorporaTag('NOUN,inan,masc sing,nomn'))],
#  [('.', '.', OpencorporaTag('PNCT'))],
#  [('если', 'если', OpencorporaTag('CONJ'))],
#  [('я', 'я', OpencorporaTag('NPRO,1per sing,nomn'))],
#  [('откажусь',
#    'отказаться',
#    OpencorporaTag('VERB,perf,intr sing,1per,futr,indc'))],
#  [('от', 'от', OpencorporaTag('PREP'))],
#  [('сдачи', 'сдача', OpencorporaTag('NOUN,inan,femn sing,gent'))],
#  [('обществознания',
#    'обществознание',
#    OpencorporaTag('NOUN,inan,neut sing,gent')),
#   ('обществознания',
#    'обществознание',
#    OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('обществознания',
#    'обществознание',
#    OpencorporaTag('NOUN,inan,neut plur,accs'))],
#  [(',', ',', OpencorporaTag('PNCT'))],
#  [('старые', 'старое', OpencorporaTag('NOUN,inan,neut plur,nomn')),
#   ('старые', 'старое', OpencorporaTag('NOUN,inan,neut plur,accs')),
#   ('старые', 'старый', OpencorporaTag('ADJF,Qual plur,nomn')),
#   ('старые', 'старый', OpencorporaTag('ADJF,Qual inan,plur,accs'))],
#  [('баллы', 'балл', OpencorporaTag('NOUN,inan,masc plur,nomn')),
#   ('баллы', 'балл', OpencorporaTag('NOUN,inan,masc plur,accs'))],
#  [('не', 'не', OpencorporaTag('PRCL'))],
#  [('аннулируются',
#    'аннулироваться',
#    OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'))],
#  [('?', '?', OpencorporaTag('PNCT'))],
#  [('пикча', 'пикч', OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent')),
#   ('пикча', 'пикч', OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,accs')),
#   ('пикча', 'пикча', OpencorporaTag('NOUN,inan,femn sing,nomn'))],
#  [('рандом', 'ранд', OpencorporaTag('NOUN,inan,masc sing,ablt'))],
#  [(')', ')', OpencorporaTag('PNCT'))]]
